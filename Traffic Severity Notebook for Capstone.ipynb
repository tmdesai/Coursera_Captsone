# %% [markdown]
# ### Coursera Capstone Project Notebook
# This notebook will be mainly used for the final capstone project I will be working on.

# %% [markdown]
# ## Title: Weather & Traffic Collisions: How Are They Related?
#
# # 1. Introduction/Problem
# Today's drivers in Seattle are inundated with several distractions on the road, including changing weather conditions, more drivers being present, city planning, smart phones, and more. With more drivers being on the road today, it is critical for drivers to better understand the various factors that may increase the chance that a driver meets with a severe accident. What I specifically want to understand is the severity of accidents that occur when the weather indicates it was raining, specifically looking at injury collision.
#
# ## Audience:
# The audience for this analysis will be drivers as well as driving trainers; by having more of this information at hand, drivers can be more cautious and safe given the influence of various factors on driving conditions.
#
# # 2. Data
# The data I will be using to execute this data will be from this link, illustrating various intersections in Seattle, weather conditions, types of accidents, locations, and more. This data is dated from 2020 and has been pulled from 20 years' of collision records from the Seattle Police Department.  This will, I hope, help us understand the impact that weather may have on drivers collisions today: https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv
#
# I am using a Jupyter notebook on my IBM Cloud for my analysis, and using Github as my main external repository to illustrate my analysis I will be performing. I am using various Python libraries for my analysis.
#
#
# # 3. Methodology
# This section represents the main component of this report; here, I will describe any exploratory data analysis I performed and why I did such analysis.
#
# First, I uploaded the CSV file to my Jupyter notebook.

# %%
import pandas as pd
import numpy as np

# %%
df_survey = pd.read_csv("https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv", index_col = 0)
df_survey
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                        X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# SEVERITYCODE
# 2            -122.323148  47.703140         1    1307       1307  3502005
# 1            -122.347294  47.647172         2   52200      52200  2607959
# 1            -122.334540  47.607871         3   26700      26700  1482393
# 1            -122.334803  47.604803         4    1144       1144  3503937
# 2            -122.306426  47.545739         5   17700      17700  1807429
# 1            -122.387598  47.690575         6  320840     322340  E919477
# 1            -122.338485  47.618534         7   83300      83300  3282542
# 2            -122.320780  47.614076         9  330897     332397  EA30304
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv',
            index_col=0)
df

# %%
df.dtypes
# Out:
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# SEGLANEKEY          int64
# ...

# %%
df['WEATHER'].value_counts().to_frame()
# Out:
#                           WEATHER
# Clear                      111135
# Raining                     33145
# Overcast                    27714
# Unknown                     15091
# Snowing                       907
# Other                         832
# Fog/Smog/Smoke                569
# Sleet/Hail/Freezing Rain      113
# Blowing Sand/Dirt              56
# Severe Crosswind               25
# Partly Cloudy                   5

# %%
df(describe)

# %%
df['SEVERITYDESC'].value_counts().to_frame()
# Out:
#                                 SEVERITYDESC
# Property Damage Only Collision        136485
# Injury Collision                       58188

# %%
df_WEATHER=df.filter(['SEVERITYCODE', 'SEVERITYDESC', 'LOCATION'], axis=1)
df

# %%
df_WEATHER=df.filter(['SEVERITYCODE', 'ROADCOND','SEVERITYDESC','WEATHER'], axis=1)
df_WEATHER.head()

# %%
df_Raining=df.filter(['WEATHER','SEVERITYDESC','ROADCOND'], axis=1)
df_Raining.head()

# %%
sns.regplot(x='WEATHER', y='SEVERITYDESC', data= df)

# %%
Unique_weather = df["WEATHER"].value_counts()
Unique_weather.to_frame()

# %%
df.corr()['WEATHER'].sort_values()

# %%
X = df[['WEATHER']]
Y = df['SEVERITYDESC']
lm = LinearRegression()
lm.fit(X,Y)
lm.score(X, Y)

# %% [markdown]
# ## 4. Results
# Here I will discuss the results of my anaysis.
#
# I found that my analysis did not yield a strong connection between weather and the severity description (specifically, the correlation or connection between raining and injury collision damange. Since I decided to analyze whether rainy weather might correlate with greater instances of injury collision, I stuck with these variables, while also testing for road conditions (assuming rainy = wet road conditions) and location. However, I found that adding in more variables complicated my model and ended up focusing on severity code and weather. For some reason, although I tried to calculate correlation, develop a mathplot around the data, my notebook could not process the data. I was stumped. I then created a dataframe around severity cde and weather, finding that there was more connection between severity code 2 and rainy weather. I wanted to go back and change all my variables to test sensitivity, but found that it is best to stay focused on limited data points to find the most accuracy.

# %% [markdown]
# ## 5. Discussion
# Here I will discuss any observations I noted and any recommendations I can make based on the results.
# I find that rainy weather does have an impact on severity of accidents and the probably of getting into an injurious accident. I would use these findings to recommend to reporters informing drivers of traffic conditions that rain means increased accident probability; that drivers should be extra cognizant when driving in rainy conditions.

# %% [markdown]
# ## 6. Conclusion
# In conclusion, although rainy weather can have an impact on the possibility of drivers getting into injurious accidents, there may be other factors -- -- such as specific parts of the city, blind spots, lightning conditions, and more, that may impact the probability of getting into an accident. Given Seattle's rainy climate, and the increasing population of the city, more accidents could be on the horizon; it may be wise for the city to change speed limits or create more awareness for drivers to understand hazardous driving conditions.
